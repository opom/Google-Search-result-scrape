# %%
# !pip install selenium
! pip install webdriver_manager
# Out:
# ...
# WARNING: You are using pip version 21.2.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\ankit gupta\anaconda3\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.2.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\ankit gupta\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
driver  = webdriver.Chrome(ChromeDriverManager().install())
driver.maximize_window()
URL="https://www.google.com/maps/place/Shilp+Epitome,+Bodakdev,+Ahmedabad,+Gujarat+380054/@23.0354518,72.5033944,18z/data=!4m13!1m6!3m5!1s0x395e9bf44550dc85:0x8952a3770e6af265!2sShilp+Epitome!8m2!3d23.0356859!4d72.5040952!3m5!1s0x395e9b46faede4c9:0x2fa55f2f00a83673!8m2!3d23.0353731!4d72.5051385!10e3"

driver.get(URL)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [C:\Users\Ankit Gupta\.wdm\drivers\chromedriver\win32\97.0.4692.71\chromedriver.exe] found in cache

# %%
a =driver.find_elements(By.CLASS_NAME,'CJY91c-jRmmHf-aVTXAb-haAclf-WFkMr')

# %%
import requests
from bs4 import BeautifulSoup
soup = BeautifulSoup(driver.page_source, "html.parser")
soup.prettify()
# Out:
# '<html itemscope="" itemtype="http://schema.org/Place" jstcache="0" lang="en-IN">\n <head>\n  <link href="/maps/preview/opensearch.xml?hl=en" rel="search" title="Google Maps" type="application/opensearchdescription+xml"/>\n  <title>\n   Shilp Epitome - Google Maps\n  </title>\n  <meta content="Find local businesses, view maps and get driving directions in Google Maps." name="Description"/>\n  <meta content="initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>\n  <meta content="chrome=1" http-equiv="X-UA-Compatible"/>\n  <meta content="notranslate" name="google"/>\n  <meta content="origin" name="referrer"/>\n  <meta content="ByHT0GXztW_RcGxS0o86DBf1WtNu02FfqlcT8njnSqU" name="google-site-verification"/>\n  <meta content="Diln__r3p9-tt39P2Cl2Amvx6oFB4PATnxuFBaw6ej8" name="google-site-verification"/>\n  <meta content="Google Maps" itemprop="name"/>\n  <meta content="Google Maps" property="og:title"/>\n  <meta content="https://maps.google.com/maps/a
# ...

# %%
 Bussiness = soup.find_all('div', {'class':"CJY91c-jRmmHf-aVTXAb-haAclf-HSrbLb"})
 Bussiness
# Out:
# [<div class="CJY91c-jRmmHf-aVTXAb-haAclf-HSrbLb" jstcache="733"><div class="RnEfrd-jRmmHf-HSrbLb B9Hcub-QFlW2" jsan="t-pdDsP4P8DQQ,7.RnEfrd-jRmmHf-HSrbLb,7.B9Hcub-QFlW2" jstcache="816"><button jstcache="746" style="display:none"></button><div class="Z8fK3b" jsan="7.Z8fK3b,t-MjeqqY5XOdM" jstcache="747"> <div class="CUwbzc-content gm2-body-2"> <div class="qBF1Pd-haAclf"> <div class="qBF1Pd gm2-subtitle-alt-1" jsan="7.qBF1Pd,7.gm2-subtitle-alt-1,t-u3p6PfXaXm4" jstcache="749"> <span jstcache="762">Coffee Culture - The Ristorante Lounge, Ahmedabad</span> </div> <h1 jstcache="750" style="display:none"></h1> <span class="RnEfrd-jRmmHf-HSrbLb-title-Btuy5e-haAclf"></span> </div> <div class="section-subtitle-extension" jstcache="751"></div> <div class="ZY2y6b-RWgCYc" jsan="7.ZY2y6b-RWgCYc,t-hEqDOx2FFV0" jstcache="752"> <div class="OEvfgc-wcwwM-haAclf"> <span class="RnEfrd-jRmmHf-HSrbLb-wPzPJb-Btuy5e-haAclf" jstcache="764"></span> <span class="gm2-body-2" jsan="t-CJ3Gw1VPbAA,7.gm2-body-2" jstca
# ...

# %%
driver.page_source
# Out:
# '<html itemscope="" itemtype="http://schema.org/Place" lang="en-IN" jstcache="0"><head> <link href="/maps/preview/opensearch.xml?hl=en" title="Google Maps" rel="search" type="application/opensearchdescription+xml"> <title>Shilp Epitome - Google Maps</title> <meta content="Find local businesses, view maps and get driving directions in Google Maps." name="Description">  <meta content="initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"> <meta content="chrome=1" http-equiv="X-UA-Compatible"> <meta content="notranslate" name="google"> <meta content="origin" name="referrer"> <meta content="ByHT0GXztW_RcGxS0o86DBf1WtNu02FfqlcT8njnSqU" name="google-site-verification"> <meta content="Diln__r3p9-tt39P2Cl2Amvx6oFB4PATnxuFBaw6ej8" name="google-site-verification">   <meta content="Google Maps" itemprop="name"> <meta content="Google Maps" property="og:title"> <meta content="https://maps.google.com/maps/api/staticmap?center=23.0354518%2C72.5033944&amp;zoom=18
# ...

# %%
data={}
ids = 0
for  Bussines in  Bussiness:
    meta = {}
    ids += 1
    name=Bussines.find('div', {'class':"qBF1Pd gm2-subtitle-alt-1"})
    address=Bussines.find_all('div', {'class':"ZY2y6b-RWgCYc"})
    rating= Bussines.find_all('div', {'class':"OEvfgc-wcwwM-haAclf"})
    meta['name']=name.getText()
    for addres in address[0:2]:
        meta['address']=addres.getText()
    for rates in rating:
        meta['rating']=rates.getText()
    data[ids] = meta
data
# Out:
# {1: {'name': ' Coffee Culture - The Ristorante Lounge, Ahmedabad ',
#   'address': '     · Cafe     · 3rd floor, Shilp Epitome, Sindhubhavan Marg       · Open until 12:00 am     ',
#   'rating': '  4.2(1,512)   · ₹₹₹   '},
#  2: {'name': ' Cloves Rooftop Restaurant & Cafe ',
#   'address': '     · Vegetarian     · Shilp Epitome, 3rd floor, 405, Sindhubhavan Marg, Behind Rajpath Club       · Open until 11:00 pm     ',
#   'rating': '  4.1(285)    '},
#  3: {'name': ' Shilp Epitome ',
#   'address': '     · Real estate developer     · Rajpath Rangoli Road,राजपथ रंगोली मार्ग,Rajpath Club Road, Sindhubhavan Marg, Near Infostech       · Open until 7:00 pm     ',
#   'rating': '  4.5(176)    '},
#  4: {'name': ' Heads Up for Tails Pet Store & Spa ',
#   'address': '     · Pet store     · Shop No. 3 Shilp Epitome, Rajpath Rangoli Rd, behind Infostretch.       · Open until 9:00 pm     · 081604 41199     ',
#   'rating': '  5.0(158)    '},
# ...

# %%
import pandas as pd
df=pd.DataFrame(data)
df.T
# Out:
#                                                  name  \
# 1    Coffee Culture - The Ristorante Lounge, Ahmed...
# 2                   Cloves Rooftop Restaurant & Cafe
# 3                                      Shilp Epitome
# 4                 Heads Up for Tails Pet Store & Spa
# 5    Windzoon Technologies - Digital Marketing Age...
# 6               Aipxperts Technolabs Private Limited
# 7                 Nexus Corporate Solution Pvt. Ltd.
# 8                                Vox360 Ways Pvt Ltd
# 9                                  Perfect Renewtech
# 10                                    Atharva System
#
#                                               address                   rating
# 1        · Cafe     · 3rd floor, Shilp Epitome, Si...    4.2(1,512)   · ₹₹₹
# 2        · Vegetarian     · Shilp Epitome, 3rd flo...             4.1(285)
# 3        · Real estate developer     · Rajpath Ran...             4.5(176)
# ...
